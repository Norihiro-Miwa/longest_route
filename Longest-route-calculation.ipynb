# %% [markdown]
# # Longest-Route calculation
#
# Rule: calculate the longest route, given that we cannot pass the same station more than twice.
#
# Special thanks to https://note.com/jnot/n/nd2c9469e4fd8

# %% [markdown]
# ## import necessary libraries

# %%
pip install graphillion
# Out:
# Collecting graphillion
#   Downloading Graphillion-1.5.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.1 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from graphillion) (0.16.0)
# Building wheels for collected packages: graphillion
#   Building wheel for graphillion (setup.py) ... done
#   Created wheel for graphillion: filename=Graphillion-1.5-cp37-cp37m-linux_x86_64.whl size=1729078 sha256=92f3a6f0923a9944cb216c50f4d42df08fbea3dd32331aa1134ec97a0d1cd6f7
#   Stored in directory: /root/.cache/pip/wheels/94/c0/df/458922008944dec578822e0b371d7adb9699814ed95a3f8cbc
# Successfully built graphillion
# Installing collected packages: graphillion
# Successfully installed graphillion-1.5

# %%
from graphillion import GraphSet as gs
import graphillion.tutorial as tl
import gc
import pandas as pd
import time
import itertools

# %% [markdown]
# ##data import
#
# imported as edges. The fourth column "in_use" is to define whether the given line is in operation or not.

# %%
#read Railway section data[s_sta,e_sta,dist,in_use]
#df_list_tmp = pd.read_csv("/path/to/Austria_Edges_v10.csv", sep=',')
df_list_tmp = pd.read_csv("/content/drive/MyDrive/2021_Vienna/Longest Route/Data/Austria_Edges_v10.csv", sep=',')

df_list = df_list_tmp[df_list_tmp["in_use"] == 1]

# %%
df_list
# Out:
#                 s_sta           e_sta  dist  in_use
# 0    Lochau-Hoerbranz  Sud(Lauterach)   8.0       1
# 1      Lustenau Markt  Sud(Lauterach)   6.6       1
# 2      Sud(Lauterach)       Feldkirch  32.2       1
# 3           Feldkirch           Tisis   7.3       1
# 4             Bludenz         Schruns  12.7       1
# ..                ...             ...   ...     ...
# 161       Ganserndorf   Bernhardsthal  43.9       1
# 162         Stockerau     Floridsdorf  21.6       1
# 163         Stockerau            Retz  55.6       1
# 164              Retz      Drosendorf  39.8       1
# 165              Retz   Unterretzbach   4.2       1
#
# [166 rows x 4 columns]

# %% [markdown]
# ##create list of end/start stations

# %%
start_end_station_set = set.union(set(df_list['s_sta']),set(df_list['e_sta']))
print(len(start_end_station_set))
print(start_end_station_set)

df_start_end_station = pd.DataFrame(
    data={'start_set': list(start_end_station_set), 
          'end_set': list(start_end_station_set)
    }
)
# Out:
# 141
# {'Zelamsee', 'Hainfeld', 'Pamhagen', 'Burmoos', 'Voecklamarkt', 'Alt-nagelberg', 'Arnoldstein', 'Ebenfurth', 'Emmersdorf', 'Stainach-irdning', 'Bischofshofen', 'Bad-Fischau-brunn', 'Laa-thaya', 'Waidhofen-pastalozzi', 'Weisenbach-Neuhaus', 'Wien-FJB', 'Jenbach', 'Villach', 'Grunau-im-almtal', 'Gutenstein', 'Parndorf-Ort', 'Schrambach', 'Woergl', 'Attersee', 'Scheibbs', 'Kufstein', 'Braunau-am-inn', 'Weiz', 'Unterretzbach', 'Waidhofen', 'Neusiedl-am-see', 'Heidenreichstein', 'Krimml', 'Kammer-schoerfling', 'Lieboch', 'St.Michael', 'Enns', 'Poechlarn', 'Bruck-an-der-mur', 'Drosendorf', 'Innsbruck', 'Feldkirch', 'Flughafen', 'Leopoldau', 'Stockerau', 'Unzmarkt', 'Brenner', 'Lamprechtshausen', 'Bad-Gleichenberg', 'Wernstein', 'Ganserndorf', 'Niederspaching', 'Feldbach', 'Koeschach-Mauthen', 'Wetmannstaetten', 'Marchegg', 'St.pantaleon', 'St.michael', 'Mariazell', 'Lambach', 'Baumgarten', 'Tullun', 'Handelskai', 'Summerau', 'Fehring', 'Graz', 'Leobersdorf', 'Traisen', 'Herzogenburg', 'Trimmelkam', 'Sollenau', 'linz', 'Tullun-donau', 'Sigmundsherberg', 'Linz', 'Thoeri-Maglern', 'Mogersdorf', 'Hutteldorf', 'Schruns', 'Heiligenstadt', 'Silian', 'Grossgerungs', 'VillachWarmbad', 'Kledering', 'Absdorf-hippersdorf', 'Tullnerfeld', 'Wies-elbiswald', 'Koeflach', 'Amstetten', 'Lustenau Markt', 'Steindorf', 'Neumarkt-Kallham', 'Wien-west', 'Penzing', 'Rosenbach', 'Lochau-Hoerbranz', 'Klagenfurt', 'Scharding', 'Sud(Lauterach)', 'Mayrhofen', 'Litschau', 'Wolfsthal', 'Wels', 'Gleisdorf', 'Ried-im-innkreis', 'St.polten', 'Meidling', 'St.Veit-an-der-Glan', 'Spittal-milstaettersee', 'Attnang-Puchheim', 'Nickelsdorf', 'Hbf', 'Kastenreith', 'Schwarzach-St.Veit', 'Peuerbach', 'Kittsee', 'Voeklabruck', 'Floridsdorf', 'Wr-Neustadt', 'Bludenz', 'Bernhardsthal', 'Puchberg', 'Selzthal', 'Retz', 'Hadersdorf', 'St.Valentin', 'Krems-donau', 'Tisis', 'Parndorf', 'Tullun-stadt', 'St.nikola-struden', 'Graz-Werndorf', 'Salzburg', 'Wulkaprodersdorf', 'Hochschneeberg', 'Gmunden', 'Loipersbach-schattendorf', 'Spielfeld-strass', 'Gmund', 'Wolfsberg', 'Rennweg'}

# %% [markdown]
# ## create graph

# %%
univ = []
weights = {}

for i, v in df_list.iterrows():
   edge = (v['s_sta'], v['e_sta'])
   univ.append(edge)
   weights[edge] = v['dist']

gs.set_universe(univ)

# %% [markdown]
# ##Main calculation

# %%
AAA = []
BBB = []

#define start and end points
for i, v in df_start_end_station.iterrows():
   sta_s=(v['start_set'])
   sta_e=(v['end_set'])
   AAA.append(sta_s)
   BBB.append(sta_e)


 #function to calculate and print the distance 
def route_calc(start,end):
  paths = gs.paths(start, end) #this single sentence can calculate all the paths btwn start and end (distance-based, decend)
  try:
    for path in paths.max_iter(weights): #extract the longest one
      max_path = path
      #print(path)
      break
    distance = 0
    for edge in max_path:
      distance += weights[edge]
    return distance

  except: 
    "StopIteration"
    return "NA"

#print the longest distance for all O-D pairs 
i_dst=0.0
j=1
time_sta=time.perf_counter()
longest_temp = 0
for A in AAA:
 for B in BBB:
   start=A
   end = B
   if(start != end ):
     i=route_calc(start,end)
     time_end=time.perf_counter()
     tim=time_end - time_sta
     if i != "NA":
       if i >= longest_temp:
        print("Calculation "+str(j)+", "+start+" to "+end+", Distance: ,"+str(i)+", elapsed time (s): "+str(tim))
        longest_temp = i
     else:
       print("Calculation "+str(j)+", "+start+" to "+end+", calculation failed,"+str(tim))

     j=j+1
 BBB.pop(0)
# Out:
# Calculation 1, Zelamsee to Hainfeld, Distance: ,1254.1, elapsed time (s): 0.02107507800002395
# Calculation 2, Zelamsee to Pamhagen, Distance: ,1421.7999999999997, elapsed time (s): 0.03535143300001664
# Calculation 3, Zelamsee to Burmoos, Distance: ,2086.2999999999997, elapsed time (s): 0.04909956700001317
# Calculation 18, Zelamsee to Grunau-im-almtal, Distance: ,2118.7, elapsed time (s): 0.26221496900001284
# Calculation 430, Burmoos to Jenbach, Distance: ,2204.2, elapsed time (s): 6.442867963000026
# Calculation 454, Burmoos to Innsbruck, Distance: ,2238.5999999999995, elapsed time (s): 6.828608722000013
# Calculation 455, Burmoos to Feldkirch, Distance: ,2395.7000000000003, elapsed time (s): 6.845691795000022
# Calculation 503, Burmoos to Lustenau Markt, Distance: ,2434.5, elapsed time (s): 7.74546594200001
# Calculation 509, Burmoos to Lochau-Hoerbranz, Distance: ,2435.9, elapsed time (s): 7.855634530000003
# Calculation 2438, Grunau-im-almtal to Lustenau Markt, Distance: ,2466.9, elapsed time (s): 40.66078355900001
# Calculation 2444, Grunau-im-almtal to Lochau-Hoerbranz, Distance: ,2468.3, elapsed time (s): 40.80062778600001

# %% [markdown]
# The potential longest route is now known. However, the nodes in this graph may not necessarily the start/end points. Consider the network below. In such case, the longest route is not A-B-C-D; it's A-B-C-D-(one station before)B. We call it type-P as the graph looks capital letter P. Therefore, considering that the maximum edge length is approx. 100km, we need to write down the paths longer than 2350km. These all are the potential path, and we need to (manually) consider whether there exist any type-P solutions.

# %% [markdown]
# #write down all the routes over 2.350 km

# %%
define_long_thres = 2350

AAA = []
BBB = []

#define start and end points
for i, v in df_start_end_station.iterrows():
   sta_s=(v['start_set'])
   sta_e=(v['end_set'])
   AAA.append(sta_s)
   BBB.append(sta_e)
j = 1
for A in AAA:
 for B in BBB:
   start=A
   end = B
   if(start != end ):
     i=route_calc(start,end)
     time_end=time.perf_counter()
     tim=time_end - time_sta
     if i != "NA":
       if i >= define_long_thres:
         print("Calculation "+str(j)+", "+start+" to "+end+", Distance: ,"+str(i)+", elapsed time (s): "+str(tim))
     j=j+1
 BBB.pop(0)
# Out:
# Calculation 455, Burmoos to Feldkirch, Distance: ,2395.7000000000003, elapsed time (s): 959.879147633
# Calculation 492, Burmoos to Schruns, Distance: ,2387.6000000000004, elapsed time (s): 960.402672485
# Calculation 503, Burmoos to Lustenau Markt, Distance: ,2434.5, elapsed time (s): 960.5665097630001
# Calculation 509, Burmoos to Lochau-Hoerbranz, Distance: ,2435.9, elapsed time (s): 960.6499468920001
# Calculation 512, Burmoos to Sud(Lauterach), Distance: ,2427.9, elapsed time (s): 960.695768631
# Calculation 533, Burmoos to Bludenz, Distance: ,2374.9, elapsed time (s): 960.983158989
# Calculation 541, Burmoos to Tisis, Distance: ,2403.0, elapsed time (s): 961.097299522
# Calculation 591, Voecklamarkt to Feldkirch, Distance: ,2375.4, elapsed time (s): 961.8207974540001
# Calculation 628, Voecklamarkt to Schruns, Distance: ,2367.3, elapsed time (s): 962.3484274960001
# Calculation 639, Voecklamarkt to Lustenau Markt, Distance: ,2414.2, elapsed time (s): 962.5057302770001
# Calculation 645, Voecklamarkt to Lochau-Hoerbranz, Distance: ,2415.6, elapsed time (s): 962.5954153509999
# Calculation 648, Voecklamarkt to Sud(Lauterach), Distance: ,2407.6, elapsed time (s): 962.644927499
# Calculation 669, Voecklamarkt to Bludenz, Distance: ,2354.6, elapsed time (s): 962.919657937
# Calculation 677, Voecklamarkt to Tisis, Distance: ,2382.7, elapsed time (s): 963.025416466
# Calculation 1434, Bischofshofen to Lustenau Markt, Distance: ,2358.9999999999995, elapsed time (s): 973.610639403
# Calculation 1440, Bischofshofen to Lochau-Hoerbranz, Distance: ,2360.3999999999996, elapsed time (s): 973.6874155570001
# Calculation 1443, Bischofshofen to Sud(Lauterach), Distance: ,2352.3999999999996, elapsed time (s): 973.726152599
# Calculation 2390, Grunau-im-almtal to Feldkirch, Distance: ,2428.1000000000004, elapsed time (s): 986.632388106
# Calculation 2427, Grunau-im-almtal to Schruns, Distance: ,2420.0000000000005, elapsed time (s): 987.200637551
# Calculation 2438, Grunau-im-almtal to Lustenau Markt, Distance: ,2466.9, elapsed time (s): 987.3962886270001
# Calculation 2444, Grunau-im-almtal to Lochau-Hoerbranz, Distance: ,2468.3, elapsed time (s): 987.5091508349999
# Calculation 2447, Grunau-im-almtal to Sud(Lauterach), Distance: ,2460.3, elapsed time (s): 987.557468948
# Calculation 2468, Grunau-im-almtal to Bludenz, Distance: ,2407.3, elapsed time (s): 987.9688419490001
# Calculation 2476, Grunau-im-almtal to Tisis, Distance: ,2435.4, elapsed time (s): 988.103352243
# Calculation 2985, Attersee to Feldkirch, Distance: ,2388.7000000000003, elapsed time (s): 997.4565910430001
# Calculation 3022, Attersee to Schruns, Distance: ,2380.6000000000004, elapsed time (s): 997.9579848430001
# Calculation 3033, Attersee to Lustenau Markt, Distance: ,2427.5, elapsed time (s): 998.1055907950001
# Calculation 3039, Attersee to Lochau-Hoerbranz, Distance: ,2428.9, elapsed time (s): 998.192644277
# Calculation 3042, Attersee to Sud(Lauterach), Distance: ,2420.9, elapsed time (s): 998.25412575
# Calculation 3063, Attersee to Bludenz, Distance: ,2367.9, elapsed time (s): 998.5606507150001
# Calculation 3071, Attersee to Tisis, Distance: ,2396.0, elapsed time (s): 998.6681778070001
# Calculation 3330, Braunau-am-inn to Feldkirch, Distance: ,2350.8, elapsed time (s): 1002.1887109680001
# Calculation 3378, Braunau-am-inn to Lustenau Markt, Distance: ,2389.6, elapsed time (s): 1002.8911160540001
# Calculation 3384, Braunau-am-inn to Lochau-Hoerbranz, Distance: ,2391.0, elapsed time (s): 1002.974270148
# Calculation 3387, Braunau-am-inn to Sud(Lauterach), Distance: ,2383.0, elapsed time (s): 1003.0156416039999
# Calculation 3416, Braunau-am-inn to Tisis, Distance: ,2358.1000000000004, elapsed time (s): 1003.4261847160001
# Calculation 4100, Kammer-schoerfling to Feldkirch, Distance: ,2370.2000000000003, elapsed time (s): 1012.7399897990001
# Calculation 4137, Kammer-schoerfling to Schruns, Distance: ,2362.1000000000004, elapsed time (s): 1013.228017418
# Calculation 4148, Kammer-schoerfling to Lustenau Markt, Distance: ,2409.0, elapsed time (s): 1013.3995314680001
# Calculation 4154, Kammer-schoerfling to Lochau-Hoerbranz, Distance: ,2410.4, elapsed time (s): 1013.4827305220001
# Calculation 4157, Kammer-schoerfling to Sud(Lauterach), Distance: ,2402.4, elapsed time (s): 1013.544978425
# Calculation 4186, Kammer-schoerfling to Tisis, Distance: ,2377.5, elapsed time (s): 1013.937520658
# Calculation 4926, Feldkirch to Lamprechtshausen, Distance: ,2397.8, elapsed time (s): 1023.9333926859999
# Calculation 4928, Feldkirch to Wernstein, Distance: ,2382.2, elapsed time (s): 1023.9610596069999
# Calculation 4930, Feldkirch to Niederspaching, Distance: ,2354.6000000000004, elapsed time (s): 1023.986312886
# Calculation 4932, Feldkirch to Koeschach-Mauthen, Distance: ,2358.3999999999996, elapsed time (s): 1024.012688727
# Calculation 4938, Feldkirch to Lambach, Distance: ,2371.8, elapsed time (s): 1024.096685831
# Calculation 4948, Feldkirch to Trimmelkam, Distance: ,2404.7000000000003, elapsed time (s): 1024.231880477
# Calculation 4959, Feldkirch to Silian, Distance: ,2351.8, elapsed time (s): 1024.377186875
# Calculation 4976, Feldkirch to Scharding, Distance: ,2377.4, elapsed time (s): 1024.606993463
# Calculation 4981, Feldkirch to Wels, Distance: ,2385.1000000000004, elapsed time (s): 1024.6775315950001
# Calculation 4988, Feldkirch to Attnang-Puchheim, Distance: ,2354.6000000000004, elapsed time (s): 1024.782975741
# Calculation 4993, Feldkirch to Peuerbach, Distance: ,2358.2, elapsed time (s): 1024.854646288
# Calculation 4995, Feldkirch to Voeklabruck, Distance: ,2359.3, elapsed time (s): 1024.881043327
# Calculation 5011, Feldkirch to Salzburg, Distance: ,2372.7, elapsed time (s): 1025.104346867
# Calculation 5014, Feldkirch to Gmunden, Distance: ,2401.1000000000004, elapsed time (s): 1025.142492447
# Calculation 5530, Lamprechtshausen to Schruns, Distance: ,2389.7000000000003, elapsed time (s): 1032.013507105
# Calculation 5541, Lamprechtshausen to Lustenau Markt, Distance: ,2436.6, elapsed time (s): 1032.165424976
# Calculation 5547, Lamprechtshausen to Lochau-Hoerbranz, Distance: ,2438.0, elapsed time (s): 1032.26182221
# Calculation 5550, Lamprechtshausen to Sud(Lauterach), Distance: ,2430.0, elapsed time (s): 1032.302625429
# Calculation 5571, Lamprechtshausen to Bludenz, Distance: ,2377.0, elapsed time (s): 1032.58396976
# Calculation 5579, Lamprechtshausen to Tisis, Distance: ,2405.1, elapsed time (s): 1032.705811305
# Calculation 5713, Wernstein to Schruns, Distance: ,2374.1, elapsed time (s): 1034.503836446
# Calculation 5724, Wernstein to Lustenau Markt, Distance: ,2420.9999999999995, elapsed time (s): 1034.647185891
# Calculation 5730, Wernstein to Lochau-Hoerbranz, Distance: ,2422.3999999999996, elapsed time (s): 1034.7265044
# Calculation 5733, Wernstein to Sud(Lauterach), Distance: ,2414.3999999999996, elapsed time (s): 1034.771529885
# Calculation 5754, Wernstein to Bludenz, Distance: ,2361.4, elapsed time (s): 1035.0560827900001
# Calculation 5762, Wernstein to Tisis, Distance: ,2389.5, elapsed time (s): 1035.164778611
# Calculation 5903, Niederspaching to Lustenau Markt, Distance: ,2393.4, elapsed time (s): 1037.03896865
# Calculation 5909, Niederspaching to Lochau-Hoerbranz, Distance: ,2394.8, elapsed time (s): 1037.113417979
# Calculation 5912, Niederspaching to Sud(Lauterach), Distance: ,2386.8, elapsed time (s): 1037.151323837
# Calculation 5941, Niederspaching to Tisis, Distance: ,2361.9, elapsed time (s): 1037.535903586
# Calculation 6067, Koeschach-Mauthen to Schruns, Distance: ,2350.2999999999993, elapsed time (s): 1039.2075000520001
# Calculation 6078, Koeschach-Mauthen to Lustenau Markt, Distance: ,2397.1999999999994, elapsed time (s): 1039.350306738
# Calculation 6084, Koeschach-Mauthen to Lochau-Hoerbranz, Distance: ,2398.5999999999995, elapsed time (s): 1039.433241426
# Calculation 6087, Koeschach-Mauthen to Sud(Lauterach), Distance: ,2390.6, elapsed time (s): 1039.480447257
# Calculation 6116, Koeschach-Mauthen to Tisis, Distance: ,2365.6999999999994, elapsed time (s): 1040.548649539
# Calculation 6568, Lambach to Schruns, Distance: ,2363.7000000000003, elapsed time (s): 1046.617862332
# Calculation 6579, Lambach to Lustenau Markt, Distance: ,2410.6, elapsed time (s): 1046.763227014
# Calculation 6585, Lambach to Lochau-Hoerbranz, Distance: ,2412.0, elapsed time (s): 1046.844962702
# Calculation 6588, Lambach to Sud(Lauterach), Distance: ,2404.0, elapsed time (s): 1046.883976784
# Calculation 6609, Lambach to Bludenz, Distance: ,2351.0000000000005, elapsed time (s): 1047.19379892
# Calculation 6617, Lambach to Tisis, Distance: ,2379.1000000000004, elapsed time (s): 1047.302259794
# Calculation 7323, Trimmelkam to Schruns, Distance: ,2396.6000000000004, elapsed time (s): 1057.0157085390001
# Calculation 7334, Trimmelkam to Lustenau Markt, Distance: ,2443.5, elapsed time (s): 1057.1612807230001
# Calculation 7340, Trimmelkam to Lochau-Hoerbranz, Distance: ,2444.9, elapsed time (s): 1057.240278811
# Calculation 7343, Trimmelkam to Sud(Lauterach), Distance: ,2436.9, elapsed time (s): 1057.294776515
# Calculation 7364, Trimmelkam to Bludenz, Distance: ,2383.9, elapsed time (s): 1057.604060066
# Calculation 7372, Trimmelkam to Tisis, Distance: ,2412.0, elapsed time (s): 1057.72001986
# Calculation 7936, Schruns to Scharding, Distance: ,2369.3, elapsed time (s): 1065.414955879
# Calculation 7941, Schruns to Wels, Distance: ,2377.0000000000005, elapsed time (s): 1065.4828027190001
# Calculation 7953, Schruns to Peuerbach, Distance: ,2350.1000000000004, elapsed time (s): 1065.669146949
# Calculation 7955, Schruns to Voeklabruck, Distance: ,2351.2000000000003, elapsed time (s): 1065.697047993
# Calculation 7971, Schruns to Salzburg, Distance: ,2364.6000000000004, elapsed time (s): 1065.907248125
# Calculation 7974, Schruns to Gmunden, Distance: ,2393.0000000000005, elapsed time (s): 1065.957662141
# Calculation 8049, Silian to Lustenau Markt, Distance: ,2390.5999999999995, elapsed time (s): 1067.066808187
# Calculation 8055, Silian to Lochau-Hoerbranz, Distance: ,2392.0, elapsed time (s): 1067.145025009
# Calculation 8058, Silian to Sud(Lauterach), Distance: ,2384.0, elapsed time (s): 1067.184003088
# Calculation 8087, Silian to Tisis, Distance: ,2359.1, elapsed time (s): 1067.587178844
# Calculation 8545, Lustenau Markt to Steindorf, Distance: ,2351.6, elapsed time (s): 1073.741746041
# Calculation 8546, Lustenau Markt to Neumarkt-Kallham, Distance: ,2384.2, elapsed time (s): 1073.756260995
# Calculation 8552, Lustenau Markt to Scharding, Distance: ,2416.2, elapsed time (s): 1073.834719356
# Calculation 8557, Lustenau Markt to Wels, Distance: ,2423.9, elapsed time (s): 1073.902035838
# Calculation 8559, Lustenau Markt to Ried-im-innkreis, Distance: ,2382.6999999999994, elapsed time (s): 1073.929305811
# Calculation 8564, Lustenau Markt to Attnang-Puchheim, Distance: ,2393.4, elapsed time (s): 1074.002154178
# Calculation 8569, Lustenau Markt to Peuerbach, Distance: ,2397.0, elapsed time (s): 1074.063323734
# Calculation 8571, Lustenau Markt to Voeklabruck, Distance: ,2398.1, elapsed time (s): 1074.089543392
# Calculation 8587, Lustenau Markt to Salzburg, Distance: ,2411.5, elapsed time (s): 1074.3208172
# Calculation 8590, Lustenau Markt to Gmunden, Distance: ,2439.9, elapsed time (s): 1074.361049476
# Calculation 8594, Lustenau Markt to Wolfsberg, Distance: ,2363.4999999999995, elapsed time (s): 1074.412522305
# Calculation 8600, Steindorf to Lochau-Hoerbranz, Distance: ,2353.0, elapsed time (s): 1074.517987252
# Calculation 8649, Neumarkt-Kallham to Lochau-Hoerbranz, Distance: ,2385.6, elapsed time (s): 1075.172227963
# Calculation 8652, Neumarkt-Kallham to Sud(Lauterach), Distance: ,2377.6, elapsed time (s): 1075.2102482
# Calculation 8681, Neumarkt-Kallham to Tisis, Distance: ,2352.7, elapsed time (s): 1075.581971836
# Calculation 8837, Lochau-Hoerbranz to Scharding, Distance: ,2417.6, elapsed time (s): 1077.698352486
# Calculation 8842, Lochau-Hoerbranz to Wels, Distance: ,2425.3, elapsed time (s): 1077.780049072
# Calculation 8844, Lochau-Hoerbranz to Ried-im-innkreis, Distance: ,2384.1, elapsed time (s): 1077.805614869
# Calculation 8849, Lochau-Hoerbranz to Attnang-Puchheim, Distance: ,2394.8, elapsed time (s): 1077.871243883
# Calculation 8854, Lochau-Hoerbranz to Peuerbach, Distance: ,2398.4, elapsed time (s): 1077.957158884
# Calculation 8856, Lochau-Hoerbranz to Voeklabruck, Distance: ,2399.5, elapsed time (s): 1077.9843227650001
# Calculation 8872, Lochau-Hoerbranz to Salzburg, Distance: ,2412.9, elapsed time (s): 1078.197642094
# Calculation 8875, Lochau-Hoerbranz to Gmunden, Distance: ,2441.3, elapsed time (s): 1078.240368835
# Calculation 8879, Lochau-Hoerbranz to Wolfsberg, Distance: ,2364.8999999999996, elapsed time (s): 1078.294675185
# Calculation 8925, Scharding to Sud(Lauterach), Distance: ,2409.6, elapsed time (s): 1078.952043158
# Calculation 8946, Scharding to Bludenz, Distance: ,2356.6, elapsed time (s): 1079.230446269
# Calculation 8954, Scharding to Tisis, Distance: ,2384.7, elapsed time (s): 1079.344089977
# Calculation 8971, Sud(Lauterach) to Wels, Distance: ,2417.3, elapsed time (s): 1079.572451085
# Calculation 8973, Sud(Lauterach) to Ried-im-innkreis, Distance: ,2376.1, elapsed time (s): 1079.599083987
# Calculation 8978, Sud(Lauterach) to Attnang-Puchheim, Distance: ,2386.8, elapsed time (s): 1079.672981774
# Calculation 8983, Sud(Lauterach) to Peuerbach, Distance: ,2390.3999999999996, elapsed time (s): 1079.732905074
# Calculation 8985, Sud(Lauterach) to Voeklabruck, Distance: ,2391.5, elapsed time (s): 1079.759025758
# Calculation 9001, Sud(Lauterach) to Salzburg, Distance: ,2404.8999999999996, elapsed time (s): 1079.9918099230001
# Calculation 9004, Sud(Lauterach) to Gmunden, Distance: ,2433.3, elapsed time (s): 1080.032555955
# Calculation 9008, Sud(Lauterach) to Wolfsberg, Distance: ,2356.8999999999996, elapsed time (s): 1080.092985611
# Calculation 9146, Wels to Bludenz, Distance: ,2364.3, elapsed time (s): 1082.009391388
# Calculation 9154, Wels to Tisis, Distance: ,2392.4, elapsed time (s): 1082.112048316
# Calculation 9227, Ried-im-innkreis to Tisis, Distance: ,2351.2, elapsed time (s): 1083.0662707230001
# Calculation 9392, Attnang-Puchheim to Tisis, Distance: ,2361.9, elapsed time (s): 1085.159165069
# Calculation 9532, Peuerbach to Tisis, Distance: ,2365.5, elapsed time (s): 1087.017471079
# Calculation 9581, Voeklabruck to Tisis, Distance: ,2366.6, elapsed time (s): 1087.735239755
# Calculation 9652, Bludenz to Salzburg, Distance: ,2351.9, elapsed time (s): 1088.721313862
# Calculation 9655, Bludenz to Gmunden, Distance: ,2380.3, elapsed time (s): 1088.769218912
# Calculation 9784, Tisis to Salzburg, Distance: ,2380.0, elapsed time (s): 1090.691767375
# Calculation 9787, Tisis to Gmunden, Distance: ,2408.4, elapsed time (s): 1090.735043197

# %% [markdown]
# Luckily, in this case, we couldn't find type-P patterns which may become longer.

# %% [markdown]
# #Extract the longest route

# %% [markdown]
# ##Show the order of edges
#
# The distance is now calculated, but the above-mentioned function does not return information about the order of edges.

# %% [markdown]
# ###Write down all the edges in the longest path.

# %%
start_sta = "Lochau-Hoerbranz"
goal_sta = "Grunau-im-almtal"
paths = gs.paths(start_sta, goal_sta)
for path in paths.max_iter(weights):
  max_path = path
  print(path)
  break
# Out:
# [('Absdorf-hippersdorf', 'Stockerau'), ('Amstetten', 'Poechlarn'), ('Amstetten', 'St.Valentin'), ('Attnang-Puchheim', 'Stainach-irdning'), ('Bischofshofen', 'Salzburg'), ('Bischofshofen', 'Stainach-irdning'), ('Bludenz', 'Innsbruck'), ('Bruck-an-der-mur', 'Graz'), ('Ebenfurth', 'Wulkaprodersdorf'), ('Fehring', 'Wr-Neustadt'), ('Feldbach', 'Fehring'), ('Feldkirch', 'Bludenz'), ('Floridsdorf', 'Leopoldau'), ('Ganserndorf', 'Leopoldau'), ('Ganserndorf', 'Marchegg'), ('Gleisdorf', 'Feldbach'), ('Graz', 'Gleisdorf'), ('Hadersdorf', 'Sigmundsherberg'), ('Handelskai', 'Heiligenstadt'), ('Handelskai', 'Rennweg'), ('Hbf', 'Flughafen'), ('Hbf', 'Marchegg'), ('Herzogenburg', 'Krems-donau'), ('Herzogenburg', 'Tullnerfeld'), ('Hutteldorf', 'Penzing'), ('Innsbruck', 'Jenbach'), ('Jenbach', 'Woergl'), ('Kastenreith', 'St.Valentin'), ('Klagenfurt', 'Rosenbach'), ('Kledering', 'Sollenau'), ('Krems-donau', 'Hadersdorf'), ('Lambach', 'Attnang-Puchheim'), ('Lambach', 'Wels'), ('Leobersdorf', 'Meidling'), ('Linz', 'Selzthal'), ('Lochau-Hoerbranz', 'Sud(Lauterach)'), ('Neumarkt-Kallham', 'Niederspaching'), ('Neumarkt-Kallham', 'Scharding'), ('Neusiedl-am-see', 'Parndorf-Ort'), ('Niederspaching', 'Linz'), ('Parndorf-Ort', 'Kledering'), ('Penzing', 'Heiligenstadt'), ('Poechlarn', 'St.polten'), ('Rennweg', 'Flughafen'), ('Ried-im-innkreis', 'Braunau-am-inn'), ('Ried-im-innkreis', 'Scharding'), ('Salzburg', 'Steindorf'), ('Selzthal', 'Kastenreith'), ('Sigmundsherberg', 'Absdorf-hippersdorf'), ('Sollenau', 'Leobersdorf'), ('Spittal-milstaettersee', 'Schwarzach-St.Veit'), ('Spittal-milstaettersee', 'Villach'), ('St.Veit-an-der-Glan', 'Klagenfurt'), ('St.Veit-an-der-Glan', 'Unzmarkt'), ('St.michael', 'Bruck-an-der-mur'), ('St.michael', 'Unzmarkt'), ('St.polten', 'Hutteldorf'), ('Steindorf', 'Braunau-am-inn'), ('Stockerau', 'Floridsdorf'), ('Sud(Lauterach)', 'Feldkirch'), ('Tullnerfeld', 'Meidling'), ('Villach', 'VillachWarmbad'), ('VillachWarmbad', 'Rosenbach'), ('Wels', 'Grunau-im-almtal'), ('Woergl', 'Zelamsee'), ('Wr-Neustadt', 'Ebenfurth'), ('Wulkaprodersdorf', 'Neusiedl-am-see'), ('Zelamsee', 'Schwarzach-St.Veit')]

# %% [markdown]
# ###Sort these edges by the appearing oreder

# %%
start_temp = start_sta
print(start_sta)
for i in range(len(max_path)):
  for start_end_pair in max_path:
    if start_sta == start_end_pair[0]:
      print("->",start_end_pair[1],end='')
      start_sta = start_end_pair[1]
      max_path.remove(start_end_pair)
      break
    elif start_sta == start_end_pair[1]:
      print("->",start_end_pair[0],end='')
      start_sta = start_end_pair[0]
      max_path.remove(start_end_pair)
      break
# Out:
# Lochau-Hoerbranz
# -> Sud(Lauterach)-> Feldkirch-> Bludenz-> Innsbruck-> Jenbach-> Woergl-> Zelamsee-> Schwarzach-St.Veit-> Spittal-milstaettersee-> Villach-> VillachWarmbad-> Rosenbach-> Klagenfurt-> St.Veit-an-der-Glan-> Unzmarkt-> St.michael-> Bruck-an-der-mur-> Graz-> Gleisdorf-> Feldbach-> Fehring-> Wr-Neustadt-> Ebenfurth-> Wulkaprodersdorf-> Neusiedl-am-see-> Parndorf-Ort-> Kledering-> Sollenau-> Leobersdorf-> Meidling-> Tullnerfeld-> Herzogenburg-> Krems-donau-> Hadersdorf-> Sigmundsherberg-> Absdorf-hippersdorf-> Stockerau-> Floridsdorf-> Leopoldau-> Ganserndorf-> Marchegg-> Hbf-> Flughafen-> Rennweg-> Handelskai-> Heiligenstadt-> Penzing-> Hutteldorf-> St.polten-> Poechlarn-> Amstetten-> St.Valentin-> Kastenreith-> Selzthal-> Linz-> Niederspaching-> Neumarkt-Kallham-> Scharding-> Ried-im-innkreis-> Braunau-am-inn-> Steindorf-> Salzburg-> Bischofshofen-> Stainach-irdning-> Attnang-Puchheim-> Lambach-> Wels-> Grunau-im-almtal
